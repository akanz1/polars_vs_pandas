# %%
import polars as pl

# %%
df = pl.read_csv("../data/hotel_bookings.csv", ignore_errors=True)
df = df.filter(pl.col("arrival_date_year") > 2015).groupby("hotel").sum()
df
# Out:
# shape: (2, 19)
# ┌──────────────┬───────┬─────────┬───────────┬─────┬────────┬───────────────────────┬──────┬───────┐
# │ hotel        ┆ is_ca ┆ lead_ti ┆ arrival_d ┆ ... ┆ days_i ┆ adr_sum               ┆ requ ┆ total │
# │ ---          ┆ ncele ┆ me_sum  ┆ ate_year_ ┆     ┆ n_wait ┆ ---                   ┆ ired ┆ _of_s │
# │ str          ┆ d_sum ┆ ---     ┆ sum       ┆     ┆ ing_li ┆ f64                   ┆ _car ┆ pecia │
# │              ┆ ---   ┆ i64     ┆ ---       ┆     ┆ st_sum ┆                       ┆ _par ┆ l_req │
# │              ┆ i64   ┆         ┆ i64       ┆     ┆ ---    ┆                       ┆ king ┆ uests │
# │              ┆       ┆         ┆           ┆     ┆ i64    ┆                       ┆ _spa ┆ _sum  │
# │              ┆       ┆         ┆           ┆     ┆        ┆                       ┆ ces_ ┆ ---   │
# │              ┆       ┆         ┆           ┆     ┆        ┆                       ┆ sum  ┆ i64   │
# │              ┆       ┆         ┆           ┆     ┆        ┆                       ┆ ---  ┆       │
# │              ┆       ┆         ┆           ┆     ┆        ┆                       ┆ i64  ┆       │
# ╞══════════════╪═══════╪═════════╪═══════════╪═════╪════════╪═══════════════════════╪══════╪═══════╡
# │ Resort Hotel ┆ 8984  ┆ 3020393 ┆ 64013115  ┆ ... ┆ 11568  ┆ 3.0609300500000524e6  ┆ 4382 ┆ 19708 │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌┤
# │ City Hotel   ┆ 27098 ┆ 7258507 ┆ 132373876 ┆ ... ┆ 215408 ┆ 7.179108929999768e6   ┆ 1730 ┆ 38929 │
# └──────────────┴───────┴─────────┴───────────┴─────┴────────┴───────────────────────┴──────┴───────┘

# %%
q = (pl.scan_csv("../data/hotel_bookings.csv", ignore_errors=True)
    .filter(pl.col("arrival_date_year") > 2015)
    .groupby("hotel")
    .agg(pl.col("*").sum())
)
df = q.collect()

# %%
df
# Out:
# shape: (2, 19)
# ┌──────────────┬───────┬─────────┬───────────┬─────┬────────┬───────────────────────┬──────┬───────┐
# │ hotel        ┆ is_ca ┆ lead_ti ┆ arrival_d ┆ ... ┆ days_i ┆ adr_sum               ┆ requ ┆ total │
# │ ---          ┆ ncele ┆ me_sum  ┆ ate_year_ ┆     ┆ n_wait ┆ ---                   ┆ ired ┆ _of_s │
# │ str          ┆ d_sum ┆ ---     ┆ sum       ┆     ┆ ing_li ┆ f64                   ┆ _car ┆ pecia │
# │              ┆ ---   ┆ i64     ┆ ---       ┆     ┆ st_sum ┆                       ┆ _par ┆ l_req │
# │              ┆ i64   ┆         ┆ i64       ┆     ┆ ---    ┆                       ┆ king ┆ uests │
# │              ┆       ┆         ┆           ┆     ┆ i64    ┆                       ┆ _spa ┆ _sum  │
# │              ┆       ┆         ┆           ┆     ┆        ┆                       ┆ ces_ ┆ ---   │
# │              ┆       ┆         ┆           ┆     ┆        ┆                       ┆ sum  ┆ i64   │
# │              ┆       ┆         ┆           ┆     ┆        ┆                       ┆ ---  ┆       │
# │              ┆       ┆         ┆           ┆     ┆        ┆                       ┆ i64  ┆       │
# ╞══════════════╪═══════╪═════════╪═══════════╪═════╪════════╪═══════════════════════╪══════╪═══════╡
# │ Resort Hotel ┆ 8984  ┆ 3020393 ┆ 64013115  ┆ ... ┆ 11568  ┆ 3.0609300500000524e6  ┆ 4382 ┆ 19708 │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌┤
# │ City Hotel   ┆ 27098 ┆ 7258507 ┆ 132373876 ┆ ... ┆ 215408 ┆ 7.179108929999768e6   ┆ 1730 ┆ 38929 │
# └──────────────┴───────┴─────────┴───────────┴─────┴────────┴───────────────────────┴──────┴───────┘

# %%
import numpy as np

np.random.seed(12)

df = pl.DataFrame(
    {
        "nrs": [1, 2, 3, None, 5],
        "names": ["foo", "ham", "spam", "foo", "foo"],
        "random": np.random.rand(5),
        "groups": ["A", "A", "B", "C", "A"],
    }
)
print(df)
# Out:
# shape: (5, 4)
# ┌──────┬───────┬──────────────────────┬────────┐
# │ nrs  ┆ names ┆ random               ┆ groups │
# │ ---  ┆ ---   ┆ ---                  ┆ ---    │
# │ i64  ┆ str   ┆ f64                  ┆ str    │
# ╞══════╪═══════╪══════════════════════╪════════╡
# │ 1    ┆ foo   ┆ 0.15416284237967237  ┆ A      │
# ├╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┤
# │ 2    ┆ ham   ┆ 0.7400496965154048   ┆ A      │
# ├╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┤
# │ 3    ┆ spam  ┆ 0.26331501518513467  ┆ B      │
# ├╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┤
# │ null ┆ foo   ┆ 0.5337393933802977   ┆ C      │
# ├╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┤
# │ 5    ┆ foo   ┆ 0.014574962485419674 ┆ A      │
# └──────┴───────┴──────────────────────┴────────┘

# %%
df2 = df[
    [
        pl.col("random").sum().alias("sum_method"),
        pl.sum("random").alias("sum_function"),
    ]
]
print(df2)
# Out:
# shape: (1, 2)
# ┌────────────────────┬────────────────────┐
# │ sum_method         ┆ sum_function       │
# │ ---                ┆ ---                │
# │ f64                ┆ f64                │
# ╞════════════════════╪════════════════════╡
# │ 1.7058419099459294 ┆ 1.7058419099459294 │
# └────────────────────┴────────────────────┘

# %%
df3 = df[
    [
        pl.col("random").count().alias("count_method"),
        pl.count("random").alias("count_function"),
    ]
]
print(df3)
# Out:
# shape: (1, 2)
# ┌──────────────┬────────────────┐
# │ count_method ┆ count_function │
# │ ---          ┆ ---            │
# │ u32          ┆ u32            │
# ╞══════════════╪════════════════╡
# │ 5            ┆ 5              │
# └──────────────┴────────────────┘

# %%
df4 = df.select(
    [
        (
            pl.when(pl.col("random") > 0.5)
            .then(0)
            .otherwise(pl.col("random")) * pl.sum("nrs")
        ).alias("binary_function")
    ]
)
print(df4)
# Out:
# shape: (5, 1)
# ┌────────────────────┐
# │ binary_function    │
# │ ---                │
# │ f64                │
# ╞════════════════════╡
# │ 1.695791266176396  │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 0.0                │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 2.8964651670364816 │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 0.0                │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 0.1603245873396164 │
# └────────────────────┘

# %%
df5 = df[
    [
        pl.col("*"),
        pl.col("names").list().over("groups").alias("names/groups"),
        pl.col("names").set().over("groups").alias("unique_names/groups"),
    ]
]
print(df5)
# Out:
# shape: (5, 6)
# ┌──────┬───────┬──────────────────────┬────────┬────────────────────────┬────────────────────────┐
# │ nrs  ┆ names ┆ random               ┆ groups ┆ sum[names]/groups      ┆ names/groups           │
# │ ---  ┆ ---   ┆ ---                  ┆ ---    ┆ ---                    ┆ ---                    │
# │ i64  ┆ str   ┆ f64                  ┆ str    ┆ list [str]             ┆ list [str]             │
# ╞══════╪═══════╪══════════════════════╪════════╪════════════════════════╪════════════════════════╡
# │ 1    ┆ foo   ┆ 0.15416284237967237  ┆ A      ┆ ["foo", "ham", "test"] ┆ ["foo", "ham", "test"] │
# ├╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 2    ┆ ham   ┆ 0.7400496965154048   ┆ A      ┆ ["foo", "ham", "test"] ┆ ["foo", "ham", "test"] │
# ├╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 3    ┆ spam  ┆ 0.26331501518513467  ┆ B      ┆ ["spam"]               ┆ ["spam"]               │
# ├╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ null ┆ foo   ┆ 0.5337393933802977   ┆ C      ┆ ["foo"]                ┆ ["foo"]                │
# ├╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 5    ┆ test  ┆ 0.014574962485419674 ┆ A      ┆ ["foo", "ham", "test"] ┆ ["foo", "ham", "test"] │
# └──────┴───────┴──────────────────────┴────────┴────────────────────────┴────────────────────────┘

# %%
from polars.polars import PyExpr

# %%
help(PyExpr)
# Out:
# Help on class PyExpr in module builtins:
#
# class PyExpr(object)
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __floordiv__(self, value, /)
#  |      Return self//value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __le__(self, value, /)
#  |      Return self<=value.
#  |
#  |  __lt__(self, value, /)
#  |      Return self<value.
#  |
#  |  __mod__(self, value, /)
#  |      Return self%value.
#  |
#  |  __mul__(self, value, /)
#  |      Return self*value.
#  |
#  |  __ne__(self, value, /)
#  |      Return self!=value.
#  |
#  |  __radd__(self, value, /)
#  |      Return value+self.
#  |
#  |  __rfloordiv__(self, value, /)
#  |      Return value//self.
#  |
#  |  __rmod__(self, value, /)
#  |      Return value%self.
#  |
#  |  __rmul__(self, value, /)
#  |      Return value*self.
#  |
#  |  __rsub__(self, value, /)
#  |      Return value-self.
#  |
#  |  __rtruediv__(self, value, /)
#  |      Return value/self.
#  |
#  |  __sub__(self, value, /)
#  |      Return self-value.
#  |
#  |  __truediv__(self, value, /)
#  |      Return self/value.
#  |
#  |  abs(...)
#  |
#  |  agg_groups(...)
#  |
#  |  alias(...)
#  |
#  |  arg_max(...)
#  |
#  |  arg_min(...)
#  |
#  |  arg_sort(...)
#  |
#  |  arg_unique(...)
#  |
#  |  arr_lengths(...)
#  |
#  |  backward_fill(...)
#  |
#  |  cast(...)
#  |
#  |  count(...)
#  |
#  |  cumcount(...)
#  |
#  |  cummax(...)
#  |
#  |  cummin(...)
#  |
#  |  cumprod(...)
#  |
#  |  cumsum(...)
#  |
#  |  date_buckets(...)
#  |
#  |  day(...)
#  |
#  |  diff(...)
#  |
#  |  dot(...)
#  |
#  |  dt_epoch_seconds(...)
#  |
#  |  eq(...)
#  |
#  |  exclude(...)
#  |
#  |  explode(...)
#  |
#  |  fill_nan(...)
#  |
#  |  fill_null(...)
#  |
#  |  fill_null_with_strategy(...)
#  |
#  |  filter(...)
#  |
#  |  first(...)
#  |
#  |  floor(...)
#  |
#  |  forward_fill(...)
#  |
#  |  gt(...)
#  |
#  |  gt_eq(...)
#  |
#  |  hash(...)
#  |
#  |  head(...)
#  |
#  |  hour(...)
#  |
#  |  interpolate(...)
#  |
#  |  is_duplicated(...)
#  |
#  |  is_finite(...)
#  |
#  |  is_first(...)
#  |
#  |  is_in(...)
#  |
#  |  is_infinite(...)
#  |
#  |  is_nan(...)
#  |
#  |  is_not(...)
#  |
#  |  is_not_nan(...)
#  |
#  |  is_not_null(...)
#  |
#  |  is_null(...)
#  |
#  |  is_unique(...)
#  |
#  |  keep_name(...)
#  |
#  |  kurtosis(...)
#  |
#  |  last(...)
#  |
#  |  list(...)
#  |
#  |  lower_bound(...)
#  |
#  |  lst_get(...)
#  |
#  |  lst_max(...)
#  |
#  |  lst_mean(...)
#  |
#  |  lst_min(...)
#  |
#  |  lst_reverse(...)
#  |
#  |  lst_sort(...)
#  |
#  |  lst_sum(...)
#  |
#  |  lst_unique(...)
#  |
#  |  lt(...)
#  |
#  |  lt_eq(...)
#  |
#  |  map(...)
#  |
#  |  max(...)
#  |
#  |  mean(...)
#  |
#  |  median(...)
#  |
#  |  min(...)
#  |
#  |  minute(...)
#  |
#  |  mode(...)
#  |
#  |  month(...)
#  |
#  |  n_unique(...)
#  |
#  |  nanosecond(...)
#  |
#  |  neq(...)
#  |
#  |  ordinal_day(...)
#  |
#  |  over(...)
#  |
#  |  pow(...)
#  |
#  |  prefix(...)
#  |
#  |  quantile(...)
#  |
#  |  rank(...)
#  |
#  |  reinterpret(...)
#  |
#  |  repeat_by(...)
#  |
#  |  reshape(...)
#  |
#  |  reverse(...)
#  |
#  |  rolling_apply(...)
#  |
#  |  rolling_max(...)
#  |
#  |  rolling_mean(...)
#  |
#  |  rolling_median(...)
#  |
#  |  rolling_min(...)
#  |
#  |  rolling_quantile(...)
#  |
#  |  rolling_skew(...)
#  |
#  |  rolling_std(...)
#  |
#  |  rolling_sum(...)
#  |
#  |  rolling_var(...)
#  |
#  |  round(...)
#  |
#  |  second(...)
#  |
#  |  set(...)
#  |
#  |  shift(...)
#  |
#  |  shift_and_fill(...)
#  |
#  |  shuffle(...)
#  |
#  |  skew(...)
#  |
#  |  slice(...)
#  |
#  |  sort_by(...)
#  |
#  |  sort_with(...)
#  |
#  |  std(...)
#  |
#  |  str_concat(...)
#  |
#  |  str_contains(...)
#  |
#  |  str_extract(...)
#  |
#  |  str_json_path_match(...)
#  |
#  |  str_lengths(...)
#  |
#  |  str_parse_date(...)
#  |
#  |  str_parse_datetime(...)
#  |
#  |  str_replace(...)
#  |
#  |  str_replace_all(...)
#  |
#  |  str_slice(...)
#  |
#  |  str_to_lowercase(...)
#  |
#  |  str_to_uppercase(...)
#  |
#  |  strftime(...)
#  |
#  |  suffix(...)
#  |
#  |  sum(...)
#  |
#  |  tail(...)
#  |
#  |  take(...)
#  |
#  |  take_every(...)
#  |
#  |  timestamp(...)
#  |
#  |  to_physical(...)
#  |
#  |  unique(...)
#  |
#  |  upper_bound(...)
#  |
#  |  var(...)
#  |
#  |  week(...)
#  |
#  |  weekday(...)
#  |
#  |  year(...)
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  __new__(*args, **kwargs) from builtins.type
#  |      Create and return a new object.  See help(type) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __hash__ = None
